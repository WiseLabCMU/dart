# %%
# %cd ..
# Out:
# /home/tianshu/dart

# %%
import json

import numpy as np
from matplotlib import pyplot as plt
from scipy.io import loadmat

from dart import VirtualRadar

# %%
with open("data/cubes/cubes.json") as f:
    cfg = json.load(f)
sensor = VirtualRadar(**cfg)

fig, axs = plt.subplots(4, 4, figsize=(16, 16))
axs = axs.reshape(-1)

y = loadmat("data/cubes/cubes_tl.mat")
t = (np.arange(axs.shape[0]) * y['rad'].shape[0] / axs.shape[0]).astype(int)
for i, ax in zip(t, axs):
    sensor.plot_image(ax, y['rad'][i])
    ax.set_title(i)

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].plot(*y['pos'][:, :2].T)
axs[1].plot(*y['pos'][:, 2:].T)
axs[2].plot(*y['pos'][:, [0, 2]].T)
